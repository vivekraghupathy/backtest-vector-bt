# %%
import pandas as pd
import yfinance as yf

# %%
universe=['CESC.NS', 'SWIGGY.NS', 'BRITANNIA.NS', 'RAMCOCEM.NS', 'MANKIND.NS', 'INTELLECT.NS', 'GODIGIT.NS', 'ETERNAL.NS']
yf.download(universe, start='2016-03-22', end='2026-04-30', progress=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13448\382986089.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download(universe, start='2016-03-22', end='2026-04-30', progress=True)
# [*********************100%***********************]  7 of 8 completed
#
# 1 Failed download:
# ['MANKIND.NS']: Timeout('Failed to perform, curl: (28) Connection timed out after 10015 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Price       Adj Close        Close                                      \
# Ticker     MANKIND.NS BRITANNIA.NS     CESC.NS  ETERNAL.NS  GODIGIT.NS
# Date
# 2016-03-22        NaN  1201.923096   30.302595         NaN         NaN
# 2016-03-23        NaN  1190.478271   29.826059         NaN         NaN
# 2016-03-28        NaN  1146.926880   29.188574         NaN         NaN
# 2016-03-29        NaN  1128.383667   29.021317         NaN         NaN
# ...
